# %% [markdown]
# # Testing on Video

# %%
from ultralytics import YOLO
import cv2

# Load your trained YOLOv5 model
model = YOLO("/content/drive/MyDrive/FYP-II/best.pt")

# Open the video file
video_path = "/content/drive/MyDrive/FYP-II/test1.mp4"
cap = cv2.VideoCapture(video_path)

# Get video details
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the output video file
output_path = "/content/drive/MyDrive/FYP-II/output/out.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv5 inference on the frame
    results = model(frame)

    # Plot the detections on the frame
    annotated_frame = results[0].plot()

    # Write the frame to the output video
    out.write(annotated_frame)

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f" Processed video saved as: {output_path}")

# %%
from ultralytics import YOLO
import cv2

# Load your trained YOLOv5 model
model = YOLO("/content/drive/MyDrive/FYP-II/best.pt")

# Open the video file
video_path = "/content/drive/MyDrive/FYP-II/test1.mp4"
cap = cv2.VideoCapture(video_path)

# Get original video details
orig_fps = int(cap.get(cv2.CAP_PROP_FPS))
orig_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
orig_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Manually set FPS and resolution
manual_fps = 30  # Change this to your desired FPS
manual_width = 512  # Change to your desired width
manual_height = 512  # Change to your desired height

# Define the output video file (ensure filename is included)
output_path = "/content/drive/MyDrive/FYP-II/output/output_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, manual_fps, (manual_width, manual_height))

frame_count = 0  # Counter for processed frames

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Resize the frame to the chosen resolution
    frame = cv2.resize(frame, (manual_width, manual_height))

    # Run YOLOv5 inference on the frame
    results = model(frame)

    # Plot the detections on the frame
    annotated_frame = results[0].plot()

    # Write the frame to the output video
    out.write(annotated_frame)

    frame_count += 1  # Increment frame count

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f" Processed video saved as: {output_path}")
print(f" Total frames processed: {frame_count}")
print(f" Resolution: {manual_width}x{manual_height} | FPS: {manual_fps}")

# %% [markdown]
# # **Generating Logs**

# %%
# import cv2
# import requests
# import os
# from ultralytics import YOLO
# import firebase_admin
# from firebase_admin import credentials, firestore
# from datetime import datetime

# # Initialize Firebase
# def initialize_firebase():
#     try:
#         cred = credentials.Certificate("C:\Users\moham\Downloads\roadradar-55dee-firebase-adminsdk-fbsvc-04aa1a4c7e.json")
#         firebase_admin.initialize_app(cred)
#         return firestore.client()
#     except Exception as e:
#         print(f"Firebase initialization error: {e}")
#         return None

# # Function to get GPS coordinates using an API
# def get_gps_coordinates():
#     try:
#         response = requests.get("http://ip-api.com/json/")
#         data = response.json()
#         return data["lat"], data["lon"]
#     except Exception as e:
#         print(f"GPS Error: {e}")
#         return None, None

# # Load YOLOv5 model
# model = YOLO("F:\final2\best_model\yolov5n_finetuned\weights\best.pt")

# # Initialize Firebase Firestore
# db = initialize_firebase()
# if not db:
#     print("Failed to initialize Firebase. Exiting...")
#     exit()

# # Open the video file
# video_path = "F:\Semester8\fyp\FYP-II\FYP-II\test1.mp4"
# cap = cv2.VideoCapture(video_path)

# # Get video properties
# fps = int(cap.get(cv2.CAP_PROP_FPS))
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# # Define output video path
# output_video_path = "F:\Semester8\fyp\FYP-II\FYP-II\output\out3.mp4"

# # Set up video writer
# fourcc = cv2.VideoWriter_fourcc(*"mp4v")
# out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# frame_count = 0
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break

#     # Run YOLO detection
#     results = model(frame)
    
#     # Get GPS coordinates
#     latitude, longitude = get_gps_coordinates()

#     # Process detections
#     for result in results:
#         for box in result.boxes:
#             crack_type = result.names[int(box.cls[0])]
#             confidence = float(box.conf[0]) * 100

#             # Create detection document
#             detection_data = {
#                 "frame": frame_count,
#                 "crack_type": crack_type,
#                 "latitude": latitude,
#                 "longitude": longitude,
#                 "timestamp": datetime.now().isoformat(),
#                 "video_source": video_path
#             }

#             # Upload to Firestore
#             try:
#                 db.collection("detections").add(detection_data)
#                 print(f"Uploaded detection: {detection_data}")
#             except Exception as e:
#                 print(f"Firestore upload error: {e}")

#     # Annotate frame
#     annotated_frame = results[0].plot()

#     # Write to video
#     out.write(annotated_frame)

#     frame_count += 1

# # Release resources
# cap.release()
# out.release()
# cv2.destroyAllWindows()

# print(f"Processed video saved at: {output_video_path}")
# print("Detection data uploaded to Firestore successfully!")

# %%
# %pip install opencv-python

# %%
# %pip install ultralytics

# %%
# %pip uninstall ultralytics -y
# Out:
# Found existing installation: ultralytics 8.3.92
# Uninstalling ultralytics-8.3.92:
#   Would remove:
#     /home/abdullah-kansi/miniconda3/envs/firebaseEnv/bin/ultralytics
#     /home/abdullah-kansi/miniconda3/envs/firebaseEnv/bin/yolo
#     /home/abdullah-kansi/miniconda3/envs/firebaseEnv/lib/python3.10/site-packages/tests/*
#     /home/abdullah-kansi/miniconda3/envs/firebaseEnv/lib/python3.10/site-packages/ultralytics-8.3.92.dist-info/*
#     /home/abdullah-kansi/miniconda3/envs/firebaseEnv/lib/python3.10/site-packages/ultralytics/*
# Proceed (Y/n)? ERROR: Operation cancelled by user
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import firebase_admin
from firebase_admin import credentials, firestore
import os
from ultralytics import YOLO
import random

# Correct Firebase JSON path
firebase_json_path = "/mnt/f/final2/testing/roadradar-55dee-firebase-adminsdk-fbsvc-04aa1a4c7e.json"
if not os.path.exists(firebase_json_path):
    raise FileNotFoundError(f"Firebase JSON file not found at: {firebase_json_path}")

# Initialize Firebase
if not firebase_admin._apps:
    cred = credentials.Certificate(firebase_json_path)
    firebase_admin.initialize_app(cred)
db = firestore.client()

# Function to generate random GPS coordinates in Karachi, Pakistan
def get_coordinates():
    lat = round(random.uniform(33.9500, 34.0500), 6)  # Latitude range for Peshawar
    lon = round(random.uniform(71.4500, 71.5500), 6)
    return lat, lon

# Correct YOLO Model Path
model_path = "/mnt/f/final2/best_model/yolov5n_finetuned/weights/best.pt"
if not os.path.exists(model_path):
    raise FileNotFoundError(f"YOLO model file not found at: {model_path}")

# Load YOLOv5 model
model = YOLO(model_path)

# Open the video file
video_path = "/mnt/f/final/testing/test3.mp4"
if not os.path.exists(video_path):
    raise FileNotFoundError(f"Video file not found at: {video_path}")

cap = cv2.VideoCapture(video_path)


fps = 5
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define output paths
video_name = os.path.basename(video_path).split('.')[0]  # Extract video name (without extension)
firebase_collection_name = f"Detections_{video_name}"  # Unique collection for each video

output_video_path = f"/mnt/f/final2/testing/output/{video_name}_out.mp4"

# Set up video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

frame_count = 0
batch_logs = []  # Store logs in batches

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO detection
    results = model(frame)

    # Get dummy GPS coordinates
    latitude, longitude = get_coordinates()

    # Process detections
    for result in results:
        for box in result.boxes:
            crack_type = result.names[int(box.cls[0])]  # Get crack type
            confidence = float(box.conf[0]) * 100  # Convert to percentage

            # Prepare log entry
            log_entry = {
                "Frame": frame_count,
                "Crack Type": crack_type,
                "Latitude": latitude,
                "Longitude": longitude,
                # "Confidence": confidence
            }

            # Add log entry to batch
            batch_logs.append(log_entry)

    # Annotate frame
    annotated_frame = results[0].plot()

    # Write to video
    out.write(annotated_frame)

    # Upload logs to Firebase in batches (every 10 logs)
    if len(batch_logs) >= 10:
        for log in batch_logs:
            db.collection(firebase_collection_name).add(log)
        batch_logs = []  # Clear batch after upload

    frame_count += 1

# Upload remaining logs (if any) at the end
if batch_logs:
    for log in batch_logs:
        db.collection(firebase_collection_name).add(log)

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processed video saved at: {output_video_path}")
print(f"Detection logs saved to Firebase collection: {firebase_collection_name}")
# Out:
# 0: 288x512 (no detections), 30.2ms
# Speed: 3.2ms preprocess, 30.2ms inference, 31.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 9.0ms
# ...

# %% [markdown]
# ## updated Structure

# %%
import cv2
import firebase_admin
from firebase_admin import credentials, firestore
import os
from ultralytics import YOLO
import random
from firebase_admin.firestore import ArrayUnion
import json

# Correct Firebase JSON path
firebase_json_path = "/mnt/f/Semester8/fyp/final2/testing/key.json"
if not os.path.exists(firebase_json_path):
    raise FileNotFoundError(f"Firebase JSON file not found at: {firebase_json_path}")

# Initialize Firebase
if not firebase_admin._apps:
    cred = credentials.Certificate(firebase_json_path)
    firebase_admin.initialize_app(cred)
db = firestore.client()

# Function to generate random GPS coordinates in Peshawar, Pakistan
def get_coordinates():
    lat = round(random.uniform(33.993061, 33.997613), 6)
    lon = round(random.uniform(71.500593, 71.500803), 6)

    return lat, lon

# Correct YOLO Model Path
model_path = f"/mnt/f/Semester8/fyp/final2/best_model/yolov5n_finetuned/weights/best.pt"
if not os.path.exists(model_path):
    raise FileNotFoundError(f"YOLO model file not found at: {model_path}")

# Load YOLOv5 model
model = YOLO(model_path)

# Open the video file
video_path = "/mnt/f/Semester8/fyp/final2/testing/Final.mov"
if not os.path.exists(video_path):
    raise FileNotFoundError(f"Video file not found at: {video_path}")

cap = cv2.VideoCapture(video_path)

fps = 15
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define output paths
video_name = os.path.basename(video_path).split('.')[0]  # Extract video name (without extension)
collection_name = "Detections"  # Fixed collection name
document_id = video_name  # Document ID based on video name
output_video_path = f"/mnt/f/Semester8/fyp/final2/testing/output/{video_name}_out.mov"

# Set up video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# Reference to the Firestore document
doc_ref = db.collection(collection_name).document(document_id)

frame_count = 0
batch_logs = []  # Store logs in batches
batch_log_keys = set()  # Track unique log entries in the current batch

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO detection
    results = model(frame)

    # Get dummy GPS coordinates
    latitude, longitude = get_coordinates()

    # Process detections
    for result in results:
        for box in result.boxes:
            crack_type = result.names[int(box.cls[0])]  # Get crack type
            confidence = f"{float(box.conf[0]) * 100:.2f}%"  # Convert to percentage string

            # Prepare log entry
            log_entry = {
                "Frame": frame_count,
                "Crack Type": crack_type,
                # "Confidence": confidence,
                "Latitude": latitude,
                "Longitude": longitude
            }

            # Create a unique key for the log entry (serialize to JSON for comparison)
            log_key = json.dumps(log_entry, sort_keys=True)

            # Check for duplicates in the current batch
            if log_key not in batch_log_keys:
                batch_logs.append(log_entry)
                batch_log_keys.add(log_key)

    # Annotate frame
    annotated_frame = results[0].plot()

    # Write to video
    out.write(annotated_frame)

    # Upload logs to Firebase in batches (every 10 logs)
    if len(batch_logs) >= 10:
        doc_ref.set({
            "logs": ArrayUnion(batch_logs),
            "timestamp": firestore.SERVER_TIMESTAMP
        }, merge=True)
        batch_logs = []  # Clear batch after upload
        batch_log_keys.clear()  # Clear duplicate tracking set

    frame_count += 1

# Upload remaining logs (if any) at the end
if batch_logs:
    doc_ref.set({
        "logs": ArrayUnion(batch_logs),
        "timestamp": firestore.SERVER_TIMESTAMP
    }, merge=True)

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processed video saved at: {output_video_path}")
print(f"Detection logs saved to Firebase collection: {collection_name}, document: {document_id}")
# Out:
# 0: 288x512 (no detections), 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 14.5ms
# Speed: 1.6ms preprocess, 14.5ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# ...

# %%
pip install geocoder
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
#   Cell In[2], line 1
#     pip install geopy
#         ^
# SyntaxError: invalid syntax
